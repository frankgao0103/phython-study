# %%
from random import randrange

coin_user,coin_bot = 5,5
rounds_of_game = 0

def bet(dice,wager):
    if dice == 7:
        print(f'the dice is {dice};\nDRAW!\n')
        return 0
    elif dice < 7:
        if wager ==  's':
            print(f'the dice is {dice};\nYOU WIN!\n')
            return 1
        else :
            print(f'the dice is {dice};\nYOU LOST!\n')
            return -1
    elif dice > 7:
        if wager ==  's':
            print(f'the dice is {dice};\nYOU LOST!\n')
            return -1
        else :
            print(f'the dice is {dice};\nYOU WIN!\n')
            return 1

while True:
    print(f'You:{coin_user}\t Bot:{coin_bot}')
    dice = randrange(2,13)
    wager = input("what's your bet?")
    if wager == 'q':
        break
    elif wager in 'bs':
        result = bet(dice,wager)
        coin_user += result
        coin_bot -= result
        rounds_of_game += 1
    if coin_user == 0:
        print("Woops,you've LOST All,and game over!")
        break
    elif coin_bot == 0:
        print("Woops,the robot's LOST ALL,and game over!")
        break

print(f"You've played {rounds_of_game} rounds.\n")
print(f"You have {coin_user} coins now.\nBye!")
# Out:
# You:5	 Bot:5
# what's your bet?2
# You:5	 Bot:5
# what's your bet?2
# You:5	 Bot:5
# what's your bet?2
# You:5	 Bot:5
# what's your bet?3
# You:5	 Bot:5
# what's your bet?3
# You:5	 Bot:5
# what's your bet?b
# the dice is 3;
# YOU LOST!
#
# You:4	 Bot:6
# what's your bet?b
# the dice is 8;
# YOU WIN!
#
# You:5	 Bot:5
# what's your bet?b
# the dice is 7;
# DRAW!
#
# You:5	 Bot:5
# what's your bet?b
# the dice is 8;
# YOU WIN!
#
# You:6	 Bot:4
# what's your bet?b
# the dice is 10;
# YOU WIN!
#
# You:7	 Bot:3
# what's your bet?b
# the dice is 4;
# YOU LOST!
#
# You:6	 Bot:4
# what's your bet?b
# the dice is 6;
# YOU LOST!
#
# You:5	 Bot:5
# what's your bet?b
# the dice is 4;
# YOU LOST!
#
# You:4	 Bot:6
# what's your bet?b
# the dice is 10;
# YOU WIN!
#
# You:5	 Bot:5
# what's your bet?b
# the dice is 3;
# YOU LOST!
#
# You:4	 Bot:6
# what's your bet?b
# the dice is 4;
# YOU LOST!
#
# You:3	 Bot:7
# what's your bet?b
# the dice is 4;
# YOU LOST!
#
# You:2	 Bot:8
# what's your bet?b
# the dice is 4;
# YOU LOST!
#
# You:1	 Bot:9
# what's your bet?b
# the dice is 6;
# YOU LOST!
#
# Woops,you've LOST All,and game over!
# You've played 14 rounds.
#
# You have 0 coins now.
# Bye!
